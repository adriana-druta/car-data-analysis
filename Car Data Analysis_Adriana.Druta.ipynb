# %% [markdown]
# <a href="https://colab.research.google.com/github/adriana-druta/car-data-analysis/blob/main/Car%20Data%20Analysis_Adriana.Druta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Wrangling**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###**Importing packages**
# Python packages to cover data manipulation, visualization, and statistical analysis.

# %%
# For numerical operations
import numpy as np
# For data manipulation and analysis
import pandas as pd
# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##**Data Loading**
#
# Use Pandas to read CSV, Excel, or other file formats.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
for root, dirs, files in os.walk('content/drive/MyDrive'):
  for file in files:
    if 'data' in file.lower():
      print(os.path.join(root.file))

# %% [markdown]
# import pandas as pd
# file_id="19V7VjHs4J8idTko7NQUT95ZJO2ZQSGWh"
# url=f"http://drive.google.com/uc?id={file_id}"
# df=pd.read_csv(url)
# df

# %%
import pandas as pd
file_id="19V7VjHs4J8idTko7NQUT95ZJO2ZQSGWh"
url=f"http://drive.google.com/uc?id={file_id}"
df_raw=pd.read_csv(url)

# %%
df_raw
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ##**Understanding the Dataset**

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# **Understanding the Dataset**

# %%
df_raw.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# # **Task 1. 	Data Cleaning**

# %% [markdown]
# ### **01.** **add** or **change** or **remove** column names.
#
# Add or remove symbols (e.g., replace the space between words with the underscore symbol).
#
# Verify changes.

# %%
df_raw.columns = [col.replace(' ', '_').lower()  for col in df_raw.columns]
df_raw
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ######Lowercase all column names in new DataFrame df

# %%
df = df_raw.copy()
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11911 non-null  object
#  4   engine_hp          11845 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  float64
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
df.describe().round(2)
# Out:
#            year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# count  11914.00   11845.00          11884.00         11908.00     11914.00
# mean    2010.38     249.39              5.63             3.44        26.64
# std        7.58     109.19              1.78             0.88         8.86
# min     1990.00      55.00              0.00             2.00        12.00
# 25%     2007.00     170.00              4.00             2.00        22.00
# 50%     2015.00     227.00              6.00             4.00        26.00
# 75%     2016.00     300.00              6.00             4.00        30.00
# max     2017.00    1001.00             16.00             4.00       354.00
#
#        city_mpg  popularity        msrp
# count  11914.00    11914.00    11914.00
# mean      19.73     1554.91    40594.74
# std        8.99     1441.86    60109.10
# min        7.00        2.00     2000.00
# 25%       16.00      549.00    21000.00
# 50%       18.00     1385.00    29995.00
# ...

# %%
#Select numerical columns for correlation analysis
numeric_cols = ['year', 'engine_hp', 'engine_cylinders', 'number_of_doors', 'highway_mpg', 'city_mpg', 'popularity', 'msrp']

# Calculate the correlation matrix
corr = df[numeric_cols].corr().round(2)

# Plot the heatmap
plt.figure(figsize=(12, 10)) # Adjust figure size for better readability
sns.heatmap(corr, annot=True, cmap='viridis', center=0, fmt='.2f', square=True)
plt.title('Correlation Heatmap of Numerical Features')
plt.tight_layout()
plt.show()

# %% [markdown]
# **legend of colored squares**:
# - ***yellow***(ex.: city_mpg  with highway_mpg)  and ***dark blue*** (ex.: engine_cylinders with city_mpg or highway_mpg) show a **strong linear correlation** between the numerical features
# - ***green*** (ex.: popularity  with city-mpg or highway_mpg, or msrp) indicates a **weak or nonlinear correlation** between the numerical features

# %% [markdown]
# ## **02. filtering** based on **year >=1995**
# - **824 deleted rows** after filtering year

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.loc[df.year < 1995]
# Out:
#          make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 17       Audi    100  1992  regular unleaded      172.0               6.0
# 18       Audi    100  1992  regular unleaded      172.0               6.0
# 19       Audi    100  1992  regular unleaded      172.0               6.0
# 20       Audi    100  1992  regular unleaded      172.0               6.0
# 21       Audi    100  1992  regular unleaded      172.0               6.0
# ...       ...    ...   ...               ...        ...               ...
# 11378   Acura  Vigor  1994  regular unleaded      176.0               5.0
# 11379   Acura  Vigor  1994  regular unleaded      176.0               5.0
# 11792  Subaru     XT  1991  regular unleaded       97.0               4.0
# 11793  Subaru     XT  1991  regular unleaded      145.0               6.0
# 11794  Subaru     XT  1991  regular unleaded      145.0               6.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# ...

# %% [markdown]
# **824 deleted rows after filtering year**

# %%
#drop the rows with year < 1995
df.drop(df.loc[df.year < 1995].index, inplace=True)

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape
# Out:
# (11090, 16)

# %% [markdown]
# ##**03. Chech and drop duplicates**
# - **487 duplicates** rows dropped

# %%
# check duplicates rows
df.duplicated().sum()
# Out:
# np.int64(487)

# %%
df.loc[df.duplicated()]
# Out:
#          make                  model  year             engine_fuel_type  \
# 14        BMW               1 Series  2013  premium unleaded (required)
# 88     Nissan                  200SX  1996             regular unleaded
# 92     Nissan                  200SX  1997             regular unleaded
# 94     Nissan                  200SX  1998             regular unleaded
# 126       BMW  3 Series Gran Turismo  2015  premium unleaded (required)
# ...       ...                    ...   ...                          ...
# 11481  Suzuki                   X-90  1998             regular unleaded
# 11603   Volvo                   XC60  2017             regular unleaded
# 11604   Volvo                   XC60  2017             regular unleaded
# 11708  Suzuki                    XL7  2008             regular unleaded
# 11717  Suzuki                    XL7  2008             regular unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df.loc[(df.make == 'BMW') & (df.model == '1 Series') & (df.engine_hp == 230) & (df.market_category == 'Luxury,Performance') & (df.city_mpg == 19)]
# Out:
#    make     model  year             engine_fuel_type  engine_hp  \
# 11  BMW  1 Series  2013  premium unleaded (required)      230.0
# 14  BMW  1 Series  2013  premium unleaded (required)      230.0
#
#     engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 11               6.0            MANUAL  rear wheel drive              2.0
# 14               6.0            MANUAL  rear wheel drive              2.0
#
#        market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# 11  Luxury,Performance      Compact         Coupe           28        19
# 14  Luxury,Performance      Compact         Coupe           28        19
#
#     popularity   msrp
# 11        3916  31500
# 14        3916  31500

# %%
df.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# **487 duplicates rows dropped**

# %%
df.shape
# Out:
# (10603, 16)

# %% [markdown]
# ## **04.** **identify** and **handle** missing values

# %%
# missing values
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       28
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3079
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
# procentage of missing values
round(df.isnull().sum() / df.shape[0] * 100, 3)
# Out:
# make                  0.000
# model                 0.000
# year                  0.000
# engine_fuel_type      0.028
# engine_hp             0.651
# engine_cylinders      0.264
# transmission_type     0.000
# driven_wheels         0.000
# number_of_doors       0.057
# market_category      29.039
# vehicle_size          0.000
# vehicle_style         0.000
# highway_mpg           0.000
# city_mpg              0.000
# popularity            0.000
# msrp                  0.000
# dtype: float64

# %% [markdown]
# **obs.: 29% of 'market_category'	have missing values.**
#
# - Must ignore or delete this column**

# %% [markdown]
# **let's start to handle in order the columns with missing values**( except 'market_category')

# %%
df.engine_fuel_type.isnull().sum()
# Out:
# np.int64(3)

# %%
df.loc[df.engine_fuel_type.isna()]
# Out:
#          make   model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 11321  Suzuki  Verona  2004              NaN      155.0               6.0
# 11322  Suzuki  Verona  2004              NaN      155.0               6.0
# 11323  Suzuki  Verona  2004              NaN      155.0               6.0
#
#       transmission_type      driven_wheels  number_of_doors market_category  \
# 11321         AUTOMATIC  front wheel drive              4.0             NaN
# 11322         AUTOMATIC  front wheel drive              4.0             NaN
# 11323         AUTOMATIC  front wheel drive              4.0             NaN
#
#       vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 11321      Midsize         Sedan           25        17         481  17199
# 11322      Midsize         Sedan           25        17         481  20199
# 11323      Midsize         Sedan           25        17         481  18499

# %%
df.loc[(df.make == 'Suzuki') & (df.transmission_type == 'AUTOMATIC') & (df.engine_hp == 155.0)]
# Out:
#          make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 1300   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1301   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1305   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1307   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1309   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1310   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1311   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1312   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1313   Suzuki   Aerio  2005  regular unleaded      155.0               4.0
# 1314   Suzuki   Aerio  2006  regular unleaded      155.0               4.0
# 1315   Suzuki   Aerio  2006  regular unleaded      155.0               4.0
# ...

# %% [markdown]
# ###### **3 missing values** in engine_fuel_type	**replaced** with 'regular unleaded'

# %%
df.loc[(df.engine_fuel_type.isna() & (df.make == 'Suzuki') & (df.transmission_type == 'AUTOMATIC') & (df.engine_hp == 155.0)), 'engine_fuel_type'] ='regular unleaded'

# %%
df.engine_fuel_type.isna().sum()
# Out:
# np.int64(0)

# %%
df.engine_hp.isnull().sum()
# Out:
# np.int64(69)

# %%
df.loc[df.engine_hp.isna()]
# Out:
#          make        model  year                engine_fuel_type  engine_hp  \
# 539      FIAT         500e  2015                        electric        NaN
# 540      FIAT         500e  2016                        electric        NaN
# 541      FIAT         500e  2017                        electric        NaN
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# ...       ...          ...   ...                             ...        ...
# 9850      Kia      Soul EV  2015                        electric        NaN
# 9851      Kia      Soul EV  2015                        electric        NaN
# 9852      Kia      Soul EV  2016                        electric        NaN
# 9853      Kia      Soul EV  2016                        electric        NaN
# 9854      Kia      Soul EV  2016                        electric        NaN
#
# ...

# %% [markdown]
# ###### **69 missing values in engine_hp**.
# - 44 electic cars ( 'engine_fuel_type' == 'electric') ; replace with median
# - 25 not electric cars  ; replace with value

# %%
df.loc[(df.engine_hp.isnull()) & (df.engine_fuel_type != 'electric')]
# Out:
#                make        model  year                  engine_fuel_type  \
# 2905        Lincoln  Continental  2017    premium unleaded (recommended)
# 2906        Lincoln  Continental  2017    premium unleaded (recommended)
# 2907        Lincoln  Continental  2017    premium unleaded (recommended)
# 2908        Lincoln  Continental  2017    premium unleaded (recommended)
# 4203           Ford       Escape  2017                  regular unleaded
# 4204           Ford       Escape  2017                  regular unleaded
# 4205           Ford       Escape  2017                  regular unleaded
# 4206           Ford       Escape  2017                  regular unleaded
# 4914           Ford     Freestar  2005                  regular unleaded
# 4915           Ford     Freestar  2005                  regular unleaded
# 4916           Ford     Freestar  2005                  regular unleaded
# 4917           Ford     Freestar  2005                  regular unleaded
# ...

# %%
df.loc[(df.make == 'Lincoln') & (df.engine_cylinders == 4) & (df.vehicle_style == 'Sedan') & (df.city_mpg == 41)]
# Out:
#          make       model  year  engine_fuel_type  engine_hp  \
# 6895  Lincoln  MKZ Hybrid  2011  regular unleaded      191.0
# 6898  Lincoln         MKZ  2015  regular unleaded      188.0
# 6900  Lincoln         MKZ  2015  regular unleaded      188.0
# 6903  Lincoln         MKZ  2016  regular unleaded      188.0
# 6906  Lincoln         MKZ  2016  regular unleaded      188.0
# 6908  Lincoln         MKZ  2017  regular unleaded        NaN
# 6910  Lincoln         MKZ  2017  regular unleaded        NaN
# 6916  Lincoln         MKZ  2017  regular unleaded        NaN
# 6918  Lincoln         MKZ  2017  regular unleaded        NaN
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 6895               4.0         AUTOMATIC  front wheel drive              4.0
# 6898               4.0         AUTOMATIC  front wheel drive              4.0
# 6900               4.0         AUTOMATIC  front wheel drive              4.0
# ...

# %% [markdown]
# #####  **use condition to replace missing valeues** -
# - exemple:
#
#   set the engine_hp = 188.0 for the specific :
#
#     Lincoln / MKZ model  / 4 cylinders / 41 city mpg
#
#   that previously had missing engine_hp values.

# %%
# Identify the specific Lincoln rows with NaN values for engine_hp
condition = (
    (df['engine_hp'].isnull()) &
    (df['make'] == 'Lincoln') &
    (df['model'] == 'MKZ') &
    (df['engine_cylinders'] == 4.0) &
    (df['city_mpg'] == 41.0)
)

# Apply the specific engine_hp value (188.0) to these identified rows
df.loc[condition, 'engine_hp'] = 188.0

# Display the modified rows to verify the change
print("Modified rows in df:")
display(df.loc[condition])
# Out:
# Modified rows in df:
#          make model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 6908  Lincoln   MKZ  2017  regular unleaded      188.0               4.0
# 6910  Lincoln   MKZ  2017  regular unleaded      188.0               4.0
# 6916  Lincoln   MKZ  2017  regular unleaded      188.0               4.0
# 6918  Lincoln   MKZ  2017  regular unleaded      188.0               4.0
#
#      transmission_type      driven_wheels  number_of_doors market_category  \
# 6908         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6910         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6916         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
# 6918         AUTOMATIC  front wheel drive              4.0   Luxury,Hybrid
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 6908      Midsize         Sedan           38        41          61  35010
# ...

# %%
df.loc[(df.engine_hp.isnull()) & (df.make == 'Lincoln') & (df.engine_cylinders == 6)]
# Out:
#          make        model  year                engine_fuel_type  engine_hp  \
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2907  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
# 2908  Lincoln  Continental  2017  premium unleaded (recommended)        NaN
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2905               6.0         AUTOMATIC    all wheel drive              4.0
# 2906               6.0         AUTOMATIC  front wheel drive              4.0
# 2907               6.0         AUTOMATIC  front wheel drive              4.0
# 2908               6.0         AUTOMATIC    all wheel drive              4.0
#
#      market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# 2905          Luxury        Large         Sedan           25        17
# ...

# %%
# Identify the specific Lincoln rows with NaN values for engine_hp
condition = (
    (df['engine_hp'].isnull()) &
    (df['make'] == 'Lincoln') &
    (df['model'] == 'Continental') &
    (df['engine_cylinders'] == 6.0) &
    (df['transmission_type'] == 'AUTOMATIC')
)

# Apply the specific engine_hp value (305.0) to these identified rows
df.loc[condition, 'engine_hp'] = 305.0

# Display the modified rows to verify the change
print("Modified rows in df:")
display(df.loc[condition])
# Out:
# Modified rows in df:
#          make        model  year                engine_fuel_type  engine_hp  \
# 2905  Lincoln  Continental  2017  premium unleaded (recommended)      305.0
# 2906  Lincoln  Continental  2017  premium unleaded (recommended)      305.0
# 2907  Lincoln  Continental  2017  premium unleaded (recommended)      305.0
# 2908  Lincoln  Continental  2017  premium unleaded (recommended)      305.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2905               6.0         AUTOMATIC    all wheel drive              4.0
# 2906               6.0         AUTOMATIC  front wheel drive              4.0
# 2907               6.0         AUTOMATIC  front wheel drive              4.0
# 2908               6.0         AUTOMATIC    all wheel drive              4.0
#
#      market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# 2905          Luxury        Large         Sedan           25        17
# ...

# %%
df.loc[(df.make == 'Lincoln')]
# Out:
#           make     model  year             engine_fuel_type  engine_hp  \
# 1650   Lincoln   Aviator  2003  premium unleaded (required)      302.0
# 1651   Lincoln   Aviator  2003  premium unleaded (required)      302.0
# 1652   Lincoln   Aviator  2003  premium unleaded (required)      302.0
# 1653   Lincoln   Aviator  2003  premium unleaded (required)      302.0
# 1654   Lincoln   Aviator  2004  premium unleaded (required)      302.0
# ...        ...       ...   ...                          ...        ...
# 10571  Lincoln  Town Car  2011     flex-fuel (unleaded/E85)      239.0
# 10572  Lincoln  Town Car  2011     flex-fuel (unleaded/E85)      239.0
# 10573  Lincoln  Town Car  2011     flex-fuel (unleaded/E85)      239.0
# 10574  Lincoln  Town Car  2011     flex-fuel (unleaded/E85)      239.0
# 11913  Lincoln    Zephyr  2006             regular unleaded      221.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
df.loc[(df.make == 'Ford') & (df.engine_cylinders == 4) & (df.transmission_type == 'AUTOMATIC')]
# Out:
#        make            model  year          engine_fuel_type  engine_hp  \
# 2095   Ford     C-Max Hybrid  2015          regular unleaded      188.0
# 2096   Ford     C-Max Hybrid  2015          regular unleaded      188.0
# 2097   Ford     C-Max Hybrid  2016          regular unleaded      188.0
# 2098   Ford     C-Max Hybrid  2016          regular unleaded      188.0
# 2099   Ford     C-Max Hybrid  2017          regular unleaded      188.0
# ...     ...              ...   ...                       ...        ...
# 10679  Ford  Transit Connect  2017  flex-fuel (unleaded/E85)      169.0
# 10681  Ford  Transit Connect  2017  flex-fuel (unleaded/E85)      169.0
# 10682  Ford  Transit Connect  2017  flex-fuel (unleaded/E85)      169.0
# 10683  Ford  Transit Connect  2017  flex-fuel (unleaded/E85)      169.0
# 10685  Ford  Transit Connect  2017  flex-fuel (unleaded/E85)      169.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
#Identify the specific Ford rows with NaN values for engine_hp
condition = (
    (df['engine_hp'].isnull()) &
    (df['make'] == 'Ford') &
    (df['model'] == 'Escape') &
    (df['engine_cylinders'] == 4.0) &
    (df['transmission_type'] == 'AUTOMATIC')
)

#Apply the specific engine_hp value (168.0) to these identified rows
df.loc[condition, 'engine_hp'] = 168.0

#Display the modified rows to verify the change
print("Modified rows in df:")
display(df.loc[condition])
# Out:
# Modified rows in df:
#       make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4203  Ford  Escape  2017  regular unleaded      168.0               4.0
# 4204  Ford  Escape  2017  regular unleaded      168.0               4.0
# 4205  Ford  Escape  2017  regular unleaded      168.0               4.0
# 4206  Ford  Escape  2017  regular unleaded      168.0               4.0
#
#      transmission_type      driven_wheels  number_of_doors market_category  \
# 4203         AUTOMATIC  front wheel drive              4.0       Crossover
# 4204         AUTOMATIC    all wheel drive              4.0       Crossover
# 4205         AUTOMATIC    all wheel drive              4.0       Crossover
# 4206         AUTOMATIC  front wheel drive              4.0       Crossover
#
#      vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 4203      Compact       4dr SUV           30        23        5657  29100
# ...

# %%
df.loc[(df.engine_hp.isnull()) & (df.make == 'Ford') & (df.engine_cylinders == 6)]
# Out:
#       make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4914  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4915  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4916  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4917  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4918  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4919  Ford  Freestar  2005  regular unleaded        NaN               6.0
#
#      transmission_type      driven_wheels  number_of_doors market_category  \
# 4914         AUTOMATIC  front wheel drive              4.0             NaN
# 4915         AUTOMATIC  front wheel drive              4.0             NaN
# 4916         AUTOMATIC  front wheel drive              4.0             NaN
# 4917         AUTOMATIC  front wheel drive              4.0             NaN
# ...

# %%
df.loc[(df.make == 'Ford') & (df.engine_cylinders == 6) & (df.driven_wheels == 'front wheel drive') & (df.model == 'Freestar') & (df.highway_mpg >20 )]
# Out:
#       make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4914  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4915  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4916  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4917  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4918  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4919  Ford  Freestar  2005  regular unleaded        NaN               6.0
# 4920  Ford  Freestar  2006  regular unleaded      193.0               6.0
# 4921  Ford  Freestar  2006  regular unleaded      201.0               6.0
# 4922  Ford  Freestar  2006  regular unleaded      193.0               6.0
# 4923  Ford  Freestar  2006  regular unleaded      201.0               6.0
# 4924  Ford  Freestar  2007  regular unleaded      201.0               6.0
# 4925  Ford  Freestar  2007  regular unleaded      201.0               6.0
# ...

# %%
#Identify the specific Ford rows with NaN values for engine_hp
condition = (
    (df['engine_hp'].isnull()) &
    (df['highway_mpg'] == 21) &
    (df['make'] == 'Ford') &
    (df['model'] == 'Freestar') &
    (df['engine_cylinders'] == 6.0) &
    (df['driven_wheels'] == 'front wheel drive') &
    (df['transmission_type'] == 'AUTOMATIC')
)

#Apply the specific engine_hp value (193.0) to these identified rows
df.loc[condition, 'engine_hp'] = 193.0

#Display the modified rows to verify the change
print("Modified rows in df:")
display(df.loc[condition])
# Out:
# Modified rows in df:
#       make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4918  Ford  Freestar  2005  regular unleaded      193.0               6.0
# 4919  Ford  Freestar  2005  regular unleaded      193.0               6.0
#
#      transmission_type      driven_wheels  number_of_doors market_category  \
# 4918         AUTOMATIC  front wheel drive              4.0             NaN
# 4919         AUTOMATIC  front wheel drive              4.0             NaN
#
#      vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 4918      Midsize  Passenger Minivan           21        16        5657  29030
# 4919      Midsize  Passenger Minivan           21        16        5657  32755

# %%
#Identify the specific Ford rows with NaN values for engine_hp
condition = (
    (df['engine_hp'].isnull()) &
    (df['highway_mpg'] == 22) &
    (df['make'] == 'Ford') &
    (df['model'] == 'Freestar') &
    (df['engine_cylinders'] == 6.0) &
    (df['driven_wheels'] == 'front wheel drive') &
    (df['transmission_type'] == 'AUTOMATIC')
)

#Apply the specific engine_hp value (201.0) to these identified rows
df.loc[condition, 'engine_hp'] = 201.0

#Display the modified rows to verify the change
print("Modified rows in df:")
display(df.loc[condition])
# Out:
# Modified rows in df:
#       make     model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 4914  Ford  Freestar  2005  regular unleaded      201.0               6.0
# 4915  Ford  Freestar  2005  regular unleaded      201.0               6.0
# 4916  Ford  Freestar  2005  regular unleaded      201.0               6.0
# 4917  Ford  Freestar  2005  regular unleaded      201.0               6.0
#
#      transmission_type      driven_wheels  number_of_doors market_category  \
# 4914         AUTOMATIC  front wheel drive              4.0             NaN
# 4915         AUTOMATIC  front wheel drive              4.0             NaN
# 4916         AUTOMATIC  front wheel drive              4.0             NaN
# 4917         AUTOMATIC  front wheel drive              4.0             NaN
#
#      vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity   msrp
# 4914      Midsize  Passenger Minivan           22        16        5657  28030
# ...

# %%
df.loc[(df.engine_hp.isnull()) & (df.model == 'Impala') & (df.make == 'Chevrolet') & (df.engine_cylinders == 6) & (df.transmission_type == 'AUTOMATIC')]
# Out:
#            make   model  year                  engine_fuel_type  engine_hp  \
# 5825  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5830  Chevrolet  Impala  2015  flex-fuel (unleaded/natural gas)        NaN
# 5831  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5833  Chevrolet  Impala  2016  flex-fuel (unleaded/natural gas)        NaN
# 5839  Chevrolet  Impala  2017  flex-fuel (unleaded/natural gas)        NaN
# 5840  Chevrolet  Impala  2017  flex-fuel (unleaded/natural gas)        NaN
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 5825               6.0         AUTOMATIC  front wheel drive              4.0
# 5830               6.0         AUTOMATIC  front wheel drive              4.0
# 5831               6.0         AUTOMATIC  front wheel drive              4.0
# 5833               6.0         AUTOMATIC  front wheel drive              4.0
# ...

# %%
# replace NaN values with 305.0
df.loc[(df.engine_hp.isnull()) & (df.model == 'Impala') & (df.make == 'Chevrolet') & (df.engine_cylinders == 6) & (df.transmission_type == 'AUTOMATIC'), 'engine_hp'] = 305.0

# %%
df.loc[(df.make == 'Mercedes-Benz') & (df.engine_fuel_type == 'diesel') & (df.engine_cylinders == 4)  & (df.highway_mpg <= 33)]
# Out:
#                make      model  year engine_fuel_type  engine_hp  \
# 5318  Mercedes-Benz  GLE-Class  2016           diesel      201.0
# 5349  Mercedes-Benz  GLK-Class  2013           diesel      200.0
# 5350  Mercedes-Benz  GLK-Class  2014           diesel      200.0
# 5355  Mercedes-Benz  GLK-Class  2015           diesel      200.0
# 6578  Mercedes-Benz    M-Class  2015           diesel        NaN
#
#       engine_cylinders transmission_type    driven_wheels  number_of_doors  \
# 5318               4.0         AUTOMATIC  all wheel drive              4.0
# 5349               4.0         AUTOMATIC  all wheel drive              4.0
# 5350               4.0         AUTOMATIC  all wheel drive              4.0
# 5355               4.0         AUTOMATIC  all wheel drive              4.0
# 6578               4.0         AUTOMATIC  all wheel drive              4.0
#
#               market_category vehicle_size vehicle_style  highway_mpg  \
# ...

# %%
# replace NaN value in engine_hp with 200
df.loc[(df.engine_hp.isnull()) & (df.make == 'Mercedes-Benz') & (df.engine_fuel_type == 'diesel') & (df.engine_cylinders == 4) & (df.highway_mpg <= 33), 'engine_hp'] = 200.0

# %%
df.loc[(df.engine_hp.isna()) & (df.engine_fuel_type == 'electric') & (df.year < 2015)]
# Out:
#             make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 4705       Honda   Fit EV  2013         electric        NaN               0.0
# 4706       Honda   Fit EV  2014         electric        NaN               0.0
# 5778  Mitsubishi   i-MiEV  2014         electric        NaN               NaN
# 6385      Nissan     Leaf  2014         electric        NaN               0.0
# 6386      Nissan     Leaf  2014         electric        NaN               0.0
# 6387      Nissan     Leaf  2014         electric        NaN               0.0
# 6921       Tesla  Model S  2014         electric        NaN               0.0
# 6922       Tesla  Model S  2014         electric        NaN               0.0
# 6923       Tesla  Model S  2014         electric        NaN               0.0
# 6924       Tesla  Model S  2014         electric        NaN               0.0
# 8374      Toyota  RAV4 EV  2013         electric        NaN               0.0
# ...

# %%
df.shape
# Out:
# (10603, 16)

# %% [markdown]
# ###**electric cars** with NaN values/ ***except 'Tesla'*** / **replaced with median** value

# %%
df.loc[(df.engine_hp.notna()) & (df.transmission_type == 'DIRECT_DRIVE'), 'engine_hp'].median()
# Out:
# 147.0

# %%
median_engine_FIAT = df.loc[df.make == 'FIAT', 'engine_hp'].median()
median_engine_FIAT
# Out:
# 160.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'FIAT'), 'engine_hp'] = median_engine_FIAT

# %%
median_engine_Ford = df.loc[df.make == 'Ford', 'engine_hp'].median()
median_engine_Ford
# Out:
# 231.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Ford'), 'engine_hp'] = median_engine_Ford

# %%
median_engine_Nissan = df.loc[df.make == 'Nissan', 'engine_hp'].median()
median_engine_Nissan
# Out:
# 261.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Nissan'), 'engine_hp'] = median_engine_Nissan

# %%
median_engine_Kia = df.loc[df.make == 'Kia', 'engine_hp'].median()
median_engine_Kia
# Out:
# 185.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Kia'), 'engine_hp'] = median_engine_Kia

# %%
median_engine_Honda = df.loc[df.make == 'Honda', 'engine_hp'].median()
median_engine_Honda
# Out:
# 185.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Honda'), 'engine_hp'] = median_engine_Honda

# %%
median_engine_Mitsubishi = df.loc[df.make == 'Mitsubishi', 'engine_hp'].median()
median_engine_Mitsubishi
# Out:
# 168.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Mitsubishi'), 'engine_hp'] = median_engine_Mitsubishi

# %%
median_engine_Toyota = df.loc[df.make == 'Toyota', 'engine_hp'].median()
median_engine_Toyota
# Out:
# 260.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Toyota'), 'engine_hp'] = median_engine_Toyota

# %%
df.loc[df.make == 'Tesla']
# Out:
#        make    model  year engine_fuel_type  engine_hp  engine_cylinders  \
# 6921  Tesla  Model S  2014         electric        NaN               0.0
# 6922  Tesla  Model S  2014         electric        NaN               0.0
# 6923  Tesla  Model S  2014         electric        NaN               0.0
# 6924  Tesla  Model S  2014         electric        NaN               0.0
# 6925  Tesla  Model S  2015         electric        NaN               0.0
# 6926  Tesla  Model S  2015         electric        NaN               0.0
# 6927  Tesla  Model S  2015         electric        NaN               0.0
# 6928  Tesla  Model S  2015         electric        NaN               0.0
# 6929  Tesla  Model S  2015         electric        NaN               0.0
# 6930  Tesla  Model S  2016         electric        NaN               0.0
# 6931  Tesla  Model S  2016         electric        NaN               0.0
# 6932  Tesla  Model S  2016         electric        NaN               0.0
# ...

# %%
# for Tesla , engine_hp value = 185
df.loc[(df.engine_hp.notna()) & (df.transmission_type == 'DIRECT_DRIVE') & (df.number_of_doors == 4) & (df.highway_mpg >= 90), 'engine_hp'].median()
# Out:
# 185.0

# %%
df.loc[(df.engine_hp.isna()) & (df.make == 'Tesla') & (df.transmission_type == 'DIRECT_DRIVE'), 'engine_hp'] = 185.0

# %%
df.engine_hp.isnull().sum()
# Out:
# np.int64(0)

# %%
df.engine_cylinders.isnull().sum()
# Out:
# np.int64(28)

# %% [markdown]
# ### **28 missing values in engine_cylinders**
# - **10** are ***electric cars***, means : engine_cylinders **== 0.0**
# - **18** are **Mazda** cars, replaced with engine_cylinders **== 6.0**

# %%
df.loc[df.engine_cylinders.isnull()]
# Out:
#             make    model  year             engine_fuel_type  engine_hp  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5778  Mitsubishi   i-MiEV  2014                     electric      168.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      154.0
# 8697       Mazda     RX-7  1995             regular unleaded      255.0
# 8698       Mazda     RX-8  2009  premium unleaded (required)      232.0
# ...

# %%
df.loc[(df.engine_cylinders.isna()) & (df.engine_fuel_type == 'electric'), 'engine_cylinders'] = 0.0

# %% [markdown]
# **28 missing** values in ***engine_cylinders*** replaced with **6.0**
# - **10 elelctic cars don't have cylinders** (if :'engine_fuel_type' == 'electric' than  **engine_cylinders == 0.0**)
# - **18 'Mazda'** cars

# %%
df.loc[(df.engine_cylinders.isna())]
# Out:
#        make model  year             engine_fuel_type  engine_hp  \
# 8697  Mazda  RX-7  1995             regular unleaded      255.0
# 8698  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8699  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8700  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8701  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8702  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8703  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8704  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8705  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8706  Mazda  RX-8  2010  premium unleaded (required)      212.0
# 8707  Mazda  RX-8  2010  premium unleaded (required)      212.0
# 8708  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8709  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8710  Mazda  RX-8  2011  premium unleaded (required)      212.0
# ...

# %%
df.loc[(df.make == 'Mazda') & (df.engine_hp >= 195)]
# Out:
#         make           model  year  engine_fuel_type  engine_hp  \
# 1723   Mazda  B-Series Truck  2007  regular unleaded      207.0
# 1728   Mazda  B-Series Truck  2007  regular unleaded      207.0
# 1729   Mazda  B-Series Truck  2008  regular unleaded      207.0
# 1730   Mazda  B-Series Truck  2008  regular unleaded      207.0
# 1733   Mazda  B-Series Truck  2009  regular unleaded      207.0
# ...      ...             ...   ...               ...        ...
# 10834  Mazda           Truck  2002  regular unleaded      207.0
# 10837  Mazda           Truck  2003  regular unleaded      207.0
# 10838  Mazda           Truck  2003  regular unleaded      207.0
# 10842  Mazda           Truck  2003  regular unleaded      207.0
# 10845  Mazda           Truck  2003  regular unleaded      207.0
#
#        engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 1723                6.0         AUTOMATIC  four wheel drive              4.0
# ...

# %%
df.loc[df.engine_cylinders.isnull()]
# Out:
#        make model  year             engine_fuel_type  engine_hp  \
# 8697  Mazda  RX-7  1995             regular unleaded      255.0
# 8698  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8699  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8700  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8701  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8702  Mazda  RX-8  2009  premium unleaded (required)      232.0
# 8703  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8704  Mazda  RX-8  2009  premium unleaded (required)      212.0
# 8705  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8706  Mazda  RX-8  2010  premium unleaded (required)      212.0
# 8707  Mazda  RX-8  2010  premium unleaded (required)      212.0
# 8708  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8709  Mazda  RX-8  2010  premium unleaded (required)      232.0
# 8710  Mazda  RX-8  2011  premium unleaded (required)      212.0
# ...

# %%
df.loc[(df.make == 'Mazda') & (df.engine_hp >= 195) & (df.number_of_doors == 2)]
# Out:
#         make  model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 8697   Mazda   RX-7  1995  regular unleaded      255.0               NaN
# 10837  Mazda  Truck  2003  regular unleaded      207.0               6.0
# 10845  Mazda  Truck  2003  regular unleaded      207.0               6.0
#
#       transmission_type     driven_wheels  number_of_doors  \
# 8697             MANUAL  rear wheel drive              2.0
# 10837            MANUAL  four wheel drive              2.0
# 10845            MANUAL  four wheel drive              2.0
#
#                  market_category vehicle_size        vehicle_style  \
# 8697   Factory Tuner,Performance      Compact                Coupe
# 10837                        NaN      Compact  Extended Cab Pickup
# 10845                        NaN      Compact  Extended Cab Pickup
#
#        highway_mpg  city_mpg  popularity   msrp
# 8697            23        15         586   8839
# 10837           17        14         586  21410
# ...

# %%
df.loc[(df.make == 'Mazda') & (df.engine_hp >= 195) & (df.number_of_doors == 2), 'engine_cylinders'] = 6.0

# %%
df.loc[(df.make == 'Mazda') & (df.engine_hp >= 195) & (df.number_of_doors == 4) & (df.driven_wheels == 'rear wheel drive'), 'engine_cylinders'] = 6.0

# %% [markdown]
# **18 rows with NaN values replaces with 6.0**

# %%
df.engine_cylinders.isnull().sum()
# Out:
# np.int64(0)

# %%
df.number_of_doors.isnull().sum()
# Out:
# np.int64(6)

# %% [markdown]
# ### **6 missing values in number_of_doors**:
#
# - 4 'Tesla' cars replace with 4
# - 2 'Ferrari' cars replace with 2

# %%
df.loc[(df.number_of_doors.isnull()) & (df.make == 'Tesla'), 'number_of_doors']= 4.0

# %%
#replace Nan values with 2.0 fron this location :df.loc[(df.number_of_doors.isnull()) & (df.make == 'Ferrari')]
df.loc[(df.number_of_doors.isnull()) & (df.make == 'Ferrari'), 'number_of_doors'] = 2.0

# %%
df.number_of_doors.isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10603, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10603 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               10603 non-null  object
#  1   model              10603 non-null  object
#  2   year               10603 non-null  int64
#  3   engine_fuel_type   10603 non-null  object
#  4   engine_hp          10603 non-null  float64
#  5   engine_cylinders   10603 non-null  float64
#  6   transmission_type  10603 non-null  object
#  7   driven_wheels      10603 non-null  object
#  8   number_of_doors    10603 non-null  float64
#  9   market_category    7524 non-null   object
#  10  vehicle_size       10603 non-null  object
#  11  vehicle_style      10603 non-null  object
#  12  highway_mpg        10603 non-null  int64
#  13  city_mpg           10603 non-null  int64
#  14  popularity         10603 non-null  int64
#  15  msrp               10603 non-null  int64
# ...

# %%
#df.Market_Category.value_count()

# %%
df.shape
# Out:
# (10603, 16)

# %%
# Reset the index of the df DataFrame
df.reset_index(drop=True, inplace=True)
df.copy()
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 10598    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10599    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10600    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10601    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 10602  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
#save df as .csv
df.to_csv('df.csv', index=False)

# %% [markdown]
# # **cleaned DataFrame / df_cleaned**
#  - without missing values
#  - without duplicate rows
#  - without column 'market_category'
#  - without year < 1995

# %%
df_cleaned = df.drop(columns=['market_category'])

# %%
df_cleaned.shape
# Out:
# (10603, 15)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10603 entries, 0 to 10602
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               10603 non-null  object
#  1   model              10603 non-null  object
#  2   year               10603 non-null  int64
#  3   engine_fuel_type   10603 non-null  object
#  4   engine_hp          10603 non-null  float64
#  5   engine_cylinders   10603 non-null  float64
#  6   transmission_type  10603 non-null  object
#  7   driven_wheels      10603 non-null  object
#  8   number_of_doors    10603 non-null  float64
#  9   vehicle_size       10603 non-null  object
#  10  vehicle_style      10603 non-null  object
#  11  highway_mpg        10603 non-null  int64
#  12  city_mpg           10603 non-null  int64
#  13  popularity         10603 non-null  int64
#  14  msrp               10603 non-null  int64
# dtypes: float64(3), int64(5), object(7)
# ...

# %% [markdown]
# # **Task 2. Feature Engineering**

# %% [markdown]
# ### **05.1** Calculate the average of city and highway MPG as **Total MPG**

# %%
df[['highway_mpg', 'city_mpg']].to_numpy()
# Out:
# array([[26, 19],
#        [28, 19],
#        [28, 20],
#        ...,
#        [23, 16],
#        [23, 16],
#        [26, 17]])

# %%
df[['highway_mpg','city_mpg']].mean(axis=1)
# Out:
# 0        22.5
# 1        23.5
# 2        24.0
# 3        23.0
# 4        23.0
#          ...
# 10598    19.5
# 10599    19.5
# 10600    19.5
# 10601    19.5
# 10602    21.5
# Length: 10603, dtype: float64

# %%
df_cleaned['Total_MPG'] = df_cleaned.apply(lambda row: np.mean([row.highway_mpg, row.city_mpg]), axis=1).astype(np.float64)
df_cleaned['Total_MPG']
# Out:
# 0        22.5
# 1        23.5
# 2        24.0
# 3        23.0
# 4        23.0
#          ...
# 10598    19.5
# 10599    19.5
# 10600    19.5
# 10601    19.5
# 10602    21.5
# Name: Total_MPG, Length: 10603, dtype: float64

# %%
df_cleaned[['highway_mpg', 'city_mpg', 'Total_MPG']]
# Out:
#        highway_mpg  city_mpg  Total_MPG
# 0               26        19       22.5
# 1               28        19       23.5
# 2               28        20       24.0
# 3               28        18       23.0
# 4               28        18       23.0
# ...            ...       ...        ...
# 10598           23        16       19.5
# 10599           23        16       19.5
# 10600           23        16       19.5
# 10601           23        16       19.5
# 10602           26        17       21.5
#
# [10603 rows x 3 columns]

# %% [markdown]
# ###new feature **Total_MPG** added to carset

# %% [markdown]
# ### **05.2** Determine **Price per HP** by dividing MSRP by Engine HP

# %%
df_cleaned['Price_per_HP'] = (df_cleaned.msrp / df_cleaned.engine_hp).round(2)
df_cleaned.Price_per_HP
# Out:
# 0        137.72
# 1        135.50
# 2        121.17
# 3        128.04
# 4        150.00
#           ...
# 10598    153.73
# 10599    188.90
# 10600    168.73
# 10601    169.73
# 10602    131.20
# Name: Price_per_HP, Length: 10603, dtype: float64

# %% [markdown]
# ###new feature **Price_per_HP** in carset

# %%
#df_cleaned.Price_per_HP = df_cleaned.apply(lambda row: np.floor([row.msrp / row.engine_hp]), axis=1).astype(np.float64)
#df_cleaned.Price_per_HP

# %%
df_cleaned
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 10598    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10599    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10600    Acura         ZDX  2012     premium unleaded (required)      300.0
# 10601    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 10602  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
round(df_cleaned.describe(),2)
# Out:
#            year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# count  10603.00   10603.00          10603.00         10603.00     10603.00
# mean    2011.75     258.85              5.68             3.48        26.75
# std        5.91     109.38              1.81             0.86         9.12
# min     1995.00      55.00              0.00             2.00        12.00
# 25%     2008.00     180.00              4.00             3.00        22.00
# 50%     2015.00     240.00              6.00             4.00        26.00
# 75%     2016.00     305.00              6.00             4.00        30.00
# max     2017.00    1001.00             16.00             4.00       354.00
#
#        city_mpg  popularity        msrp  Total_MPG  Price_per_HP
# count  10603.00    10603.00    10603.00   10603.00      10603.00
# mean      19.83     1575.33    44159.01      23.29        151.03
# std        9.37     1459.07    62495.07       8.98         99.17
# ...

# %%
# Calculate the correlation matrix for df_cleaned
numeric_cols = ['year', 'engine_hp', 'engine_cylinders', 'number_of_doors', 'highway_mpg', 'city_mpg', 'popularity', 'msrp', 'Total_MPG', 'Price_per_HP']

# 'Calculate the correlation matrix'
corr = df_cleaned[numeric_cols].corr().round(2)

# Plot the heatmap
plt.figure(figsize=(12, 10)) # Adjust figure size for better readability
sns.heatmap(corr, annot=True, cmap='viridis', center=0, fmt='.2f', square=True)
plt.title('Correlation Heatmap of Numerical Features')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Task 3. Data Analysis (EDA)**

# %% [markdown]
# ### **06.1**  Group the data by the following columns and calculate the average MSRP and Popularity for each group:
#
# - Driven_Wheels
# - Vehicle Size
# - Engine Cylinders

# %% [markdown]
# ###### **06.1.1 Group by Driven Wheels** for columns MSRP and Popularity / (calculate the average)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Gruppieren nach Antriebsart
df_grouped = df_cleaned.groupby(['driven_wheels'])[['msrp', 'popularity']].mean().round(2)

# 2. Visualisierung
df_grouped.plot(kind='bar', subplots=True, layout=(1, 2), figsize=(12, 5))
farbe_msrp = 'midnightblue'
farbe_pop = 'darkorange'
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for readability

# 3. Titel & Layout
plt.suptitle('Mean MSRP and Popularity by Driven Wheels')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
df_grouped = df_cleaned.groupby(['driven_wheels'])[['msrp', 'popularity']].mean().round(2)

fig, ax1 = plt.subplots(figsize=(14, 10))

farbe_msrp = 'midnightblue'
df_grouped['msrp'].plot(kind='bar', ax=ax1, color=farbe_msrp, alpha=0.7, label='msrp', width=0.4, position=1)
ax1.set_ylabel('Mean MSRP ($)', color=farbe_msrp)
ax1.tick_params(axis='y', labelcolor=farbe_msrp)
ax1.set_xlabel('Driven Wheels')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for readability
ax2 = ax1.twinx()
farbe_pop = 'darkorange'
df_grouped['popularity'].plot(kind='bar', ax=ax2, color=farbe_pop, alpha=0.7, label='Popularity', width=0.4, position=0)
ax2.set_ylabel('Mean Popularity', color=farbe_pop)
ax2.tick_params(axis='y', labelcolor=farbe_pop)

plt.title('Mean MSRP and Popularity by Driven Wheels', pad=15)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right', bbox_to_anchor=(0.6, 0.95))

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### **06.1.2 Group by Vehicle Size**

# %%
#df_cleaned.groupby(['vehicle_size']).agg({'msrp': 'mean', 'popularity': 'mean'}).round()
df_cleaned.groupby(['vehicle_size'])[['msrp','popularity']].mean().round(2)
# Out:
#                   msrp  popularity
# vehicle_size
# Compact       38408.26     1474.71
# Large         57177.98     1901.38
# Midsize       41505.44     1464.65

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))

df_grouped = df_cleaned.groupby(['engine_cylinders']).agg({'msrp': 'mean', 'popularity': 'mean'}).round(2)

categories = df_grouped.index
x = range(len(categories))
width = 0.35

# Plot MSRP on left y-axis
bars1 = ax1.bar([i - width/2 for i in x], df_grouped.msrp, width, label='msrp', color='steelblue')
ax1.set_xlabel('Engine_Cylinders')
ax1.set_ylabel('Mean MSRP', color='midnightblue')
ax1.tick_params(axis='y', labelcolor='midnightblue')

# Plot Popularity on right y-axis
ax2 = ax1.twinx()
bars2 = ax2.bar([i + width/2 for i in x], df_grouped.popularity, width, label='popularity', color='darkorange')
ax2.set_ylabel('Mean Popularity', color='darkorange')
ax2.tick_params(axis='y', labelcolor='darkorange')

# X-axis labels
ax1.set_xticks(list(x))
ax1.set_xticklabels(categories, rotation=45, ha='right')

# Combined legend
lines = [bars1, bars2]
ax1.legend(lines, ['MSRP', 'Popularity'], loc='upper left')

plt.title('Mean MSRP and Popularity by Engine Cylinders')
plt.tight_layout()
plt.show()

# %%
df_grouped_vehicle_size = df_cleaned.groupby(['vehicle_size'])[['msrp','popularity']].mean().round(2)

fig, ax1 = plt.subplots(figsize=(12, 7))

# Plot MSRP on left y-axis
color_msrp = 'steelblue'
df_grouped_vehicle_size['msrp'].plot(kind='bar', ax=ax1, color=color_msrp, alpha=0.7, label='msrp', width=0.4, position=1)
ax1.set_ylabel('Mean MSRP ($)', color=color_msrp)
ax1.tick_params(axis='y', labelcolor=color_msrp)
ax1.set_xlabel('Vehicle Size')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for readability

# Plot Popularity on right y-axis
ax2 = ax1.twinx()  # Create a twin Axes for Popularity
color_popularity = 'darkorange'
df_grouped_vehicle_size['popularity'].plot(kind='bar', ax=ax2, color=color_popularity, alpha=0.7, label='popularity', width=0.4, position=0)
ax2.set_ylabel('Mean Popularity', color=color_popularity)
ax2.tick_params(axis='y', labelcolor=color_popularity)

# Title and legend
plt.title('Mean MSRP and Popularity by Vehicle Size', pad=15)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 25))
fig.suptitle('Mean MSRP and Popularity by Various Categorical Features', fontsize=16, y=1.02)

# --- Plot 1: Driven_Wheels ---
df_grouped_driven_wheels = df_cleaned.groupby(['driven_wheels'])[['msrp', 'popularity']].mean().round(2)

ax1_0 = axes[0] # Primary axis for MSRP
ax2_0 = ax1_0.twinx() # Secondary axis for Popularity

color_msrp = 'midnightblue'
color_pop = 'darkorange'

df_grouped_driven_wheels['msrp'].plot(kind='bar', ax=ax1_0, color=color_msrp, alpha=0.7, label='msrp', width=0.4, position=1)
ax1_0.set_ylabel('Mean MSRP ($)', color=color_msrp)
ax1_0.tick_params(axis='y', labelcolor=color_msrp)
ax1_0.set_xlabel('Driven Wheels')
plt.setp(ax1_0.get_xticklabels(), rotation=45, ha='right') # Apply rotation

df_grouped_driven_wheels['popularity'].plot(kind='bar', ax=ax2_0, color=color_pop, alpha=0.7, label='popularity', width=0.4, position=0)
ax2_0.set_ylabel('Mean Popularity', color=color_pop)
ax2_0.tick_params(axis='y', labelcolor=color_pop)

ax1_0.set_title('Mean MSRP and Popularity by Driven Wheels')
lines1_0, labels1_0 = ax1_0.get_legend_handles_labels()
lines2_0, labels2_0 = ax2_0.get_legend_handles_labels()
ax1_0.legend(lines1_0 + lines2_0, labels1_0 + labels2_0, loc='upper right')
ax1_0.grid(axis='y', linestyle='--', alpha=0.7)

# --- Plot 2: Vehicle_Size ---
df_grouped_vehicle_size = df_cleaned.groupby(['vehicle_size'])[['msrp', 'popularity']].mean().round(2)

ax1_1 = axes[1] # Primary axis for MSRP
ax2_1 = ax1_1.twinx() # Secondary axis for Popularity

df_grouped_vehicle_size['msrp'].plot(kind='bar', ax=ax1_1, color=color_msrp, alpha=0.7, label='msrp', width=0.4, position=1)
ax1_1.set_ylabel('Mean MSRP ($)', color=color_msrp)
ax1_1.tick_params(axis='y', labelcolor=color_msrp)
ax1_1.set_xlabel('Vehicle Size')
plt.setp(ax1_1.get_xticklabels(), rotation=45, ha='right') # Apply rotation

df_grouped_vehicle_size['popularity'].plot(kind='bar', ax=ax2_1, color=color_pop, alpha=0.7, label='popularity', width=0.4, position=0)
ax2_1.set_ylabel('Mean Popularity', color=color_pop)
ax2_1.tick_params(axis='y', labelcolor=color_pop)

ax1_1.set_title('Mean MSRP and Popularity by Vehicle Size')
lines1_1, labels1_1 = ax1_1.get_legend_handles_labels()
lines2_1, labels2_1 = ax2_1.get_legend_handles_labels()
ax1_1.legend(lines1_1 + lines2_1, labels1_1 + labels2_1, loc='upper right')
ax1_1.grid(axis='y', linestyle='--', alpha=0.7)

# --- Plot 3: Engine_Cylinders ---
df_grouped_engine_cylinders = df_cleaned.groupby(['engine_cylinders'])[['msrp', 'popularity']].mean().round(2)

ax1_2 = axes[2] # Primary axis for MSRP
ax2_2 = ax1_2.twinx() # Secondary axis for Popularity

categories_cyl = df_grouped_engine_cylinders.index
x_cyl = range(len(categories_cyl))
width_cyl = 0.35

bars1_2 = ax1_2.bar([i - width_cyl/2 for i in x_cyl], df_grouped_engine_cylinders.msrp, width_cyl, label='msrp', color=color_msrp)
ax1_2.set_xlabel('Engine Cylinders')
ax1_2.set_ylabel('Mean MSRP ($)', color=color_msrp)
ax1_2.tick_params(axis='y', labelcolor=color_msrp)

bars2_2 = ax2_2.bar([i + width_cyl/2 for i in x_cyl], df_grouped_engine_cylinders.popularity, width_cyl, label='popularity', color=color_pop)
ax2_2.set_ylabel('Mean Popularity', color=color_pop)
ax2_2.tick_params(axis='y', labelcolor=color_pop)

ax1_2.set_xticks(list(x_cyl))
ax1_2.set_xticklabels(categories_cyl, rotation=45, ha='right') # Apply rotation
ax1_2.set_title('Mean MSRP and Popularity by Engine Cylinders')
lines_cyl = [bars1_2, bars2_2]
ax1_2.legend(lines_cyl, ['MSRP', 'Popularity'], loc='upper left')
ax1_2.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0.03, 1, 0.98])
plt.show()

# %% [markdown]
# ###### **Violin Plot of MSRP by Vehicle Size**
#
# - This violin plot illustrates the distribution of msrp (Manufacturer's Suggested Retail Price) for each vehicle_size category.
#
# - From this plot, we can observe how the price range and typical price points differ across compact, midsize, and large vehicles.

# %%
plt.figure(figsize=(12, 7))
sns.violinplot(x='vehicle_size', y='msrp', data=df_cleaned, hue='vehicle_size', legend=False, palette='viridis')
plt.title('Distribution of MSRP by Vehicle Size')
plt.xlabel('Vehicle Size')
plt.ylabel('MSRP')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #####This violinplot:
# -  visualizes the ***distribution of msrp*** (Manufacturer's Suggested Retail Price) **for** different ***vehicle_size categories***.
#
# - shape at each vehicle_size category shows **the density of the MSRP values**. A wider section of the violin indicates a higher concentration of cars at that particular MSRP.
#
# Distribution: You can see how the price range and the typical price points differ across compact, midsize, and large vehicles. For example, some vehicle sizes might have a wider spread of MSRPs (a fatter violin), while others might be more concentrated (a thinner violin).
#
# Comparison: **'Large' vehicles** tend to have higher MSRPs or a wider range of prices compared to **'Compact' vehicles**.
#
# Median/Quartiles: **the small box plot inside**( indicating the median and interquartile range), give further statistical insights into the distribution.

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy to avoid modifying the original df_cleaned for this step
df_correlation = df_cleaned.copy()

# Initialize LabelEncoder
le = LabelEncoder()

# Fit and transform 'vehicle_size' to numerical labels
df_correlation['vehicle_size_encoded'] = le.fit_transform(df_correlation['vehicle_size'])

# Calculate the Pearson correlation between 'msrp' and the encoded 'vehicle_size'
correlation = df_correlation['msrp'].corr(df_correlation['vehicle_size_encoded'])

print(f"Pearson correlation between MSRP and encoded Vehicle Size: {correlation:.2f}")

# Display the mean MSRP for each vehicle size as a direct confirmation of the visual trend
print("\nMean MSRP by Vehicle Size:")
display(df_cleaned.groupby('vehicle_size')['msrp'].mean().round(2))
# Out:
# Pearson correlation between MSRP and encoded Vehicle Size: 0.02
#
# Mean MSRP by Vehicle Size:
# vehicle_size
# Compact    38408.26
# Large      57177.98
# Midsize    41505.44
# Name: msrp, dtype: float64

# %% [markdown]
# - The **low Pearson correlation**, despite this clear ordering in means, suggests that while there's a general trend, the linear relationship might be subtle, or that other factors also significantly influence the MSRP.
#
#
# Conclusion: **'Vehicle Size' alone a weak linear predictor** of MSRP.

# %%
plt.figure(figsize=(12, 7))
sns.violinplot(x='driven_wheels', y='msrp', data=df_cleaned, hue='driven_wheels', legend=False, palette='Reds')
plt.title('Distribution of MSRP by Driven_Wheels')
plt.xlabel('Driven_Wheels')
plt.ylabel('MSRP')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy to avoid modifying the original df_cleaned for this step
df_correlation_driven_wheels = df_cleaned.copy()

# Initialize LabelEncoder
le = LabelEncoder()

# Fit and transform 'driven_wheels' to numerical labels
df_correlation_driven_wheels['driven_wheels_encoded'] = le.fit_transform(df_correlation_driven_wheels['driven_wheels'])

# Calculate the Pearson correlation between 'msrp' and the encoded 'driven_wheels'
correlation_driven_wheels = df_correlation_driven_wheels['msrp'].corr(df_correlation_driven_wheels['driven_wheels_encoded'])

print(f"Pearson correlation between MSRP and encoded Driven Wheels: {correlation_driven_wheels:.2f}")

# Display the mapping of original 'driven_wheels' to their encoded values
print("\nMapping of Driven Wheels to Encoded Values:")
driven_wheels_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(driven_wheels_mapping)

# Display the mean MSRP for each driven wheel type as a direct confirmation of the visual trend
print("\nMean MSRP by Driven Wheels:")
display(df_cleaned.groupby('driven_wheels')['msrp'].mean().round(2))
# Out:
# Pearson correlation between MSRP and encoded Driven Wheels: -0.02
#
# Mapping of Driven Wheels to Encoded Values:
# {'all wheel drive': np.int64(0), 'four wheel drive': np.int64(1), 'front wheel drive': np.int64(2), 'rear wheel drive': np.int64(3)}
#
# Mean MSRP by Driven Wheels:
# driven_wheels
# all wheel drive      59953.75
# four wheel drive     38540.31
# front wheel drive    24856.14
# rear wheel drive     60637.56
# Name: msrp, dtype: float64

# %% [markdown]
# - Values show that *'rear wheel drive' and 'all wheel drive' vehicles* **tend to have higher average MSRPs** compared to 'front wheel drive' and 'four wheel drive' vehicles in this dataset.
# - The *Pearson correlation coefficient* between 'MSRP' and the encoded 'Driven Wheels' is **-0.04**, indicates a **very weak, almost negligible, linear relationship** between the two variables.

# %%
plt.figure(figsize=(12, 7))
sns.violinplot(x='engine_cylinders', y='msrp', data=df_cleaned, hue='engine_cylinders', legend=False, palette='Blues')
plt.title('Distribution of MSRP vs Engine_Cylinders')
plt.xlabel('Engine_Cylinders')
plt.ylabel('MSRP')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **The** violin plot displaying **Distribution of MSRP vs Engine_Cylinders** visualizes the distribution of Manufacturer's Suggested Retail Price (MSRP) for vehicles across different engine cylinder counts.
#
# *   **Shape of the Violin:** The wider sections of each violin indicate a higher density of vehicles at a particular MSRP range for that specific number of engine cylinders. ***A narrower section suggests fewer vehicles in that price range.***
# *   **Central Box Plot:** Inside each violin, there's a mini box plot (often a white dot for the median, and a box for the interquartile range) that shows the median MSRP and the spread of the middle 50% of the data for that cylinder count.
# *   **Interpretation:** This plot allows us to observe several trends:
#     *   **Price Range:** How broad the MSRP range is for vehicles with, say, 4 cylinders versus 8 cylinders.
#     *   **Typical Price Points:** The median (white dot) helps identify the typical MSRP for each cylinder count.
#     *   **Skewness and Outliers:** You can easily spot if the MSRP distribution for a certain number of cylinders is skewed (e.g., more concentrated at lower prices with a tail towards higher prices) or if there are **potential outliers** (extreme values far from the main body of data).
# *   **Comparison:** By placing the violins side-by-side, we can directly compare the MSRP distributions across different engine cylinder configurations. Generally, vehicles with a higher number of cylinders tend to have a higher median MSRP and potentially a wider range of prices.
# *   **The Pearson correlation coefficient**   between 'MSRP' and 'Engine_Cylinders' is **0.75**. This indicates a **strong positive linear relationship** between the number of engine cylinders and the manufacturer's suggested retail price.

# %% [markdown]
# ##### 'Distribution of Vehicle_Size vs Engine_Cylinders'
#
# *   **Shape of the Violin:** The width of each violin at a given point along the Y-axis indicates the density of vehicles with that specific number of engine cylinders within that `vehicle_size` category. *A wider section means more vehicles have that cylinder count*.
#
# *   **Interpretation:** You can observe trends such as:
#     *   **Typical Cylinder Counts:** What are the most common number of cylinders for Compact, Large, and Midsize vehicles?
#     *   **Range of Cylinders:** How wide is the range of engine cylinders available for each vehicle size?
#     *   **Differences Across Sizes:** How do the distributions of `engine_cylinders` compare between different `vehicle_size` categories? For instance, do Large vehicles tend to have more cylinders than Compact vehicles?
#
# ***This plot helps in understanding the relationship between vehicle size and engine complexity*** (represented by cylinders).
#
#   -   **Pearson correlation** between Engine Cylinders and encoded Vehicle Size: **0.16** This indicates a weak positive linear relationship between the engine_cylinders and the vehicle_size.

# %%
plt.figure(figsize=(12, 7))
sns.violinplot(x='vehicle_size', y='engine_cylinders', data=df_cleaned, hue='vehicle_size', legend=False, palette='Blues')
plt.title('Distribution of Vehicle Size vs Engine_Cylinders')
plt.xlabel('Vehicle Size')
plt.ylabel('Engine_Cylinders')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy to avoid modifying the original df_cleaned for this step
df_correlation_vehicle_cylinders = df_cleaned.copy()

# Initialize LabelEncoder
le = LabelEncoder()

# Fit and transform 'vehicle_size' to numerical labels
df_correlation_vehicle_cylinders['vehicle_size_encoded'] = le.fit_transform(df_correlation_vehicle_cylinders['vehicle_size'])

# Calculate the Pearson correlation between 'engine_cylinders' and the encoded 'vehicle_size'
correlation_vehicle_cylinders = df_correlation_vehicle_cylinders['engine_cylinders'].corr(df_correlation_vehicle_cylinders['vehicle_size_encoded'])

print(f"Pearson correlation between Engine Cylinders and encoded Vehicle Size: {correlation_vehicle_cylinders:.2f}")

# Display the mapping of original 'vehicle_size' to their encoded values
print("\nMapping of Vehicle Size to Encoded Values:")
vehicle_size_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(vehicle_size_mapping)

# Display the mean Engine Cylinders for each vehicle size as a direct confirmation of the visual trend
print("\nMean Engine Cylinders by Vehicle Size:")
display(df_cleaned.groupby('vehicle_size')['engine_cylinders'].mean().round(2))
# Out:
# Pearson correlation between Engine Cylinders and encoded Vehicle Size: 0.19
#
# Mapping of Vehicle Size to Encoded Values:
# {'Compact': np.int64(0), 'Large': np.int64(1), 'Midsize': np.int64(2)}
#
# Mean Engine Cylinders by Vehicle Size:
# vehicle_size
# Compact    4.85
# Large      7.07
# Midsize    5.62
# Name: engine_cylinders, dtype: float64

# %% [markdown]
# ##### **Midsize Category analysis:**
# ***'Midsize' vehicles*** exhibit the following characteristics:
#
# - Mean MSRP: is approx. $45,217.46.
#
# - Mean Popularity:        1,682.94.
#
# - Mean Engine Cylinders:      5.30
#
#
# **Comparisson** to *'Compact' vehicles* (mean MSRP ~$37,448, mean cylinders ~4.57)
#
# and
#                   '*Large' vehicles* (mean MSRP ~$58,639, mean cylinders ~6.86)
# - 'Midsize' cars fall in the middle across these metrics, as expected. The violin plots for MSRP and engine cylinders also visually confirm this middle-ground distribution for Midsize vehicles.
#
# **Absence of electric Cars in Midsize Category**:
#
#
# **'A long Central Box'** ***indicates a larger Interquartile Range*** (IQR).
# - This means that *the middle 50%* of the data points for that particular category *are more spread out and have greater variability*.
# In a violin plot, the central box refers to the embedded box plot. This box plot provides key summary statistics for the data distribution:
#
# Median (white dot or line): This is the middle value of the data, separating the higher half from the lower half.
# Box Edges: The bottom and top edges of the box represent the first quartile (Q1) and the third quartile (Q3), respectively. This means that 50% of the data falls within this box.
# Interquartile Range (IQR):

# %% [markdown]
# ### Explanation for Midsize Vehicles
#
# The **'Midsize' vehicle category** exhibits characteristics that generally fall between 'Compact' and 'Large' vehicles across several key metrics:
#
# *   **Mean MSRP**: Approximately **$41,505.44** (as seen in `df_grouped_vehicle_size`). This positions 'Midsize' vehicles squarely between 'Compact' (mean MSRP ~$38,408) and 'Large' vehicles (mean MSRP ~$57,177).
#
# *   **Mean Popularity**: Around **1,464.65** (from `df_grouped_vehicle_size`). Similar to MSRP, its popularity score is intermediate, not the highest nor the lowest.
#
# *   **Mean Engine Cylinders**: Averaging **5.30** cylinders (from `df_grouped_engine_cylinders`). This is higher than 'Compact' vehicles (mean ~4.57) but lower than 'Large' vehicles (mean ~6.86).
#
# **Visual Confirmations from Violin Plots:**
#
# *   **Distribution of MSRP by Vehicle Size**: The violin plot for 'Midsize' vehicles shows a distribution of MSRPs that is wider than 'Compact' but often less spread out at the highest prices than 'Large', confirming its intermediate pricing range.
#
# *   **Distribution of Vehicle Size vs Engine Cylinders**: The 'Midsize' violin plot primarily shows concentrations around 4 and 6 cylinders, with some representation of 8-cylinder engines. This visually aligns with the calculated mean of 5.30 cylinders.
#
# **Outlier Analysis Observations for Midsize Vehicles:**
#
# *   **MSRP Outliers**: The analysis identified **252 MSRP outliers** in the 'Midsize' category,
# - with an **upper bound of approximately $68,898.75**.
#
# This indicates that while the bulk of midsize vehicles fall within a certain price range, there are a ***significant number of models priced considerably higher, some reaching up to $548,800.00.***
#
# *   **Engine Cylinders Outliers**: There were **89 engine cylinder outliers** in 'Midsize' vehicles.
# -  Notably, ***these include vehicles with*** **0 cylinders** (electric cars, which have no traditional engine cylinders)
# and
# -  a ***significant number of vehicles with*** **12 cylinders**.
#
# This suggests that while most midsize cars use 4 or 6 cylinders, **a small segment includes electric vehicles and high-performance luxury models with many cylinders.**

# %% [markdown]
# #### Detailed Distribution for Midsize Vehicles

# %%
midsize_df = df_cleaned[df_cleaned['vehicle_size'] == 'Midsize']

fig, axes = plt.subplots(1, 3, figsize=(20, 6))
fig.suptitle('Distribution of Key Features for Midsize Vehicles', fontsize=16, y=1.02)

# Histogram for Engine HP
sns.histplot(midsize_df['engine_hp'], bins=30, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Engine HP (Midsize Vehicles)')
axes[0].set_xlabel('Engine HP')
axes[0].set_ylabel('Frequency')
axes[0].grid(True, linestyle='--', alpha=0.7)

# Histogram for Total MPG
sns.histplot(midsize_df['Total_MPG'], bins=30, kde=True, ax=axes[1], color='lightcoral')
axes[1].set_title('Distribution of Total MPG (Midsize Vehicles)')
axes[1].set_xlabel('Total MPG')
axes[1].set_ylabel('Frequency')
axes[1].grid(True, linestyle='--', alpha=0.7)

# Histogram for MSRP
sns.histplot(midsize_df['msrp'], bins=30, kde=True, ax=axes[2], color='lightgreen')
axes[2].set_title('Distribution of MSRP (Midsize Vehicles)')
axes[2].set_xlabel('MSRP')
axes[2].set_ylabel('Frequency')
axes[2].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #### Pairplot for Midsize Vehicles
#
# This pairplot will visualize the pairwise relationships and distributions of key numerical features within the 'Midsize Vehicle' category. It helps to observe correlations, patterns, and potential clusters between:
#
# *   `engine_hp`: Engine Horsepower
# *   `Total_MPG`: Combined City and Highway Miles Per Gallon
# *   `msrp`: Manufacturer's Suggested Retail Price
# *   `popularity`: Popularity score

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure midsize_df is defined from the cleaned data for 'Midsize' vehicles
if 'midsize_df' not in locals() or midsize_df.empty:
    midsize_df = df_cleaned[df_cleaned['vehicle_size'] == 'Midsize']

# Select relevant numerical features for the pairplot to avoid overcrowding
features_for_pairplot = ['engine_hp', 'Total_MPG', 'msrp', 'popularity']

# Create the pairplot
plt.figure(figsize=(10, 8))
sns.pairplot(midsize_df[features_for_pairplot], diag_kind='kde')
plt.suptitle('Pairwise Relationships in Midsize Vehicles', y=1.02) # Adjust suptitle position
plt.show()

# %% [markdown]
# #### Pairplot for All Numerical Features in Midsize Vehicles
#
# This pairplot visualizes the pairwise relationships and distributions of all numerical features within the 'Midsize Vehicle' category. It helps to observe correlations, patterns, and potential clusters between the following numerical features:
#
# *   `year`
# *   `engine_hp`
# *   `engine_cylinders`
# *   `number_of_doors`
# *   `highway_mpg`
# *   `city_mpg`
# *   `popularity`
# *   `msrp`
# *   `Total_MPG`
# *   `Price_per_HP`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure midsize_df is defined from the cleaned data for 'Midsize' vehicles
if 'midsize_df' not in locals() or midsize_df.empty:
    midsize_df = df_cleaned[df_cleaned['vehicle_size'] == 'Midsize'].copy()

# Select all numerical features for the pairplot
# We exclude the 'Total_MPG_bin' as it's a categorical representation of Total_MPG
numerical_features = ['year', 'engine_hp', 'engine_cylinders', 'number_of_doors',
                      'highway_mpg', 'city_mpg', 'popularity', 'msrp',
                      'Total_MPG', 'Price_per_HP']

# Create the pairplot
# Due to the number of features, the plot might be dense. Adjust figsize as needed.
plt.figure(figsize=(20, 20))
sns.pairplot(midsize_df[numerical_features], diag_kind='kde')
plt.suptitle('Pairwise Relationships of All Numerical Features in Midsize Vehicles', y=1.02, fontsize=16) # Adjust suptitle position
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure midsize_df is defined from the cleaned data for 'Midsize' vehicles
if 'midsize_df' not in locals() or midsize_df.empty:
    midsize_df = df_cleaned[df_cleaned['vehicle_size'] == 'Midsize'].copy()

# Select all numerical features for the correlation matrix
numerical_features = ['year', 'engine_hp', 'engine_cylinders', 'number_of_doors',
                      'highway_mpg', 'city_mpg', 'popularity', 'msrp',
                      'Total_MPG', 'Price_per_HP']

# Calculate the correlation matrix
correlation_matrix_midsize = midsize_df[numerical_features].corr().round(2)

# Create a heatmap of the correlation matrix
plt.figure(figsize=(14, 12))
sns.heatmap(correlation_matrix_midsize, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Characteristics for Midsize Vehicles', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#vizualize the outliers for Midsize vehicle category
plt.figure(figsize=(12, 7))
sns.boxplot(x='vehicle_size', y='msrp', data=df_cleaned, palette='Blues')
# Out:
# /tmp/ipykernel_436/1614126815.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='vehicle_size', y='msrp', data=df_cleaned, palette='Blues')
# <Axes: xlabel='vehicle_size', ylabel='msrp'>

# %% [markdown]
# #####**ouliers analysis**

# %%
midsize_df = df_cleaned[df_cleaned['vehicle_size'] == 'Midsize']

def find_outliers_iqr(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = series[(series < lower_bound) | (series > upper_bound)]
    return outliers, lower_bound, upper_bound

# Check MSRP outliers for Midsize vehicles
msrp_outliers, msrp_lower, msrp_upper = find_outliers_iqr(midsize_df['msrp'])

# Check Engine Cylinders outliers for Midsize vehicles
engine_cyl_outliers, engine_cyl_lower, engine_cyl_upper = find_outliers_iqr(midsize_df['engine_cylinders'])

print(f"\n--- MSRP Outliers for Midsize Vehicles ---")
print(f"Q1: {midsize_df['msrp'].quantile(0.25):.2f}, Q3: {midsize_df['msrp'].quantile(0.75):.2f}, IQR: {midsize_df['msrp'].quantile(0.75) - midsize_df['msrp'].quantile(0.25):.2f}")
print(f"Lower Bound (MSRP): {msrp_lower:.2f}, Upper Bound (MSRP): {msrp_upper:.2f}")
print(f"Number of MSRP outliers: {len(msrp_outliers)}")
if not msrp_outliers.empty:
    print(f"Min MSRP outlier: {msrp_outliers.min():.2f}, Max MSRP outlier: {msrp_outliers.max():.2f}")

print(f"\n--- Engine Cylinders Outliers for Midsize Vehicles ---")
print(f"Q1: {midsize_df['engine_cylinders'].quantile(0.25):.2f}, Q3: {midsize_df['engine_cylinders'].quantile(0.75):.2f}, IQR: {midsize_df['engine_cylinders'].quantile(0.75) - midsize_df['engine_cylinders'].quantile(0.25):.2f}")
print(f"Lower Bound (Engine Cylinders): {engine_cyl_lower:.2f}, Upper Bound (Engine Cylinders): {engine_cyl_upper:.2f}")
print(f"Number of Engine Cylinders outliers: {len(engine_cyl_outliers)}")
if not engine_cyl_outliers.empty:
    print(f"Engine Cylinders Outliers:\n{engine_cyl_outliers.value_counts().sort_index()}")
# Out:
# --- MSRP Outliers for Midsize Vehicles ---
# Q1: 26055.00, Q3: 43192.50, IQR: 17137.50
# Lower Bound (MSRP): 348.75, Upper Bound (MSRP): 68898.75
# Number of MSRP outliers: 252
# Min MSRP outlier: 68900.00, Max MSRP outlier: 548800.00
#
# --- Engine Cylinders Outliers for Midsize Vehicles ---
# Q1: 4.00, Q3: 6.00, IQR: 2.00
# Lower Bound (Engine Cylinders): 1.00, Upper Bound (Engine Cylinders): 9.00
# Number of Engine Cylinders outliers: 89
# Engine Cylinders Outliers:
# engine_cylinders
# 0.0      3
# 10.0     1
# 12.0    85
# Name: count, dtype: int64

# %% [markdown]
# **Outlier Analysis for Midsize Vehicles in terms of MSRP and Engine Cylinders:**
#
# ** MSRP Outliers :**
# -  ** 173 outliers ** in the MSRP for Midsize vehicles.
# - lower bound for MSRP is -2759.50 and the upper bound is 87236.50.
#
#     ***means:*** any Midsize vehicle with an MSRP below the lower bound or above the upper bound is considered an outlier.
#
# - The **maximum MSRP outlier is 548800.00**.
#
# ** Engine Cylinders Outliers :**
# -  ** 290 outliers ** in the Engine Cylinders for Midsize vehicles.
# - lower bound for Engine Cylinders is 1.00 and the upper bound is 10.00.
#     ***means:*** any Midsize vehicle with an engine cylinder count below 1.0or above 10.00 is considered an outlier.
#
# - Specifically, vehicles with 0 cylinders (which are typically electric
# vehicles) and vehicles with 12 cylinders are identified as outliers.
#
# - ** 'Distribution of MSRP by Vehicle Size' **: The 'Midsize' violin plot shows a
# concentration of data in the middle, but there are indeed several data points
# extending far above the main body, **indicating high-MSRP outliers**.
#
# The embedded box plot, show these as individual points beyond the whiskers.
#
# - ** 'Distribution of Vehicle_Size vs Engine_Cylinders' **:
#
# - The 'Midsize' violin plot largely centers around 4, 6, and 8 cylinders.
# . The presence of outliers at 0 cylinders (electric cars) and 12 cylinders is visible as points outside the dense part of the violin, consistent with our quantitative findings.

# %%
df_cleaned['msrp'] = pd.to_numeric(df_cleaned['msrp'], errors='coerce')
df_cleaned['engine_cylinders'] = pd.to_numeric(df_cleaned['engine_cylinders'], errors='coerce')

df_cleaned.groupby(['engine_cylinders'])[['msrp','popularity']].mean().round(2)
# Create a pivot table to visualize the mean MSRP across Engine_Cylinders and Vehicle_Size
# Vehicle_Size is used instead of Popularity because Popularity has too many unique values for a readable heatmap.

pivot_table_data = df_cleaned.pivot_table(index='engine_cylinders', columns='vehicle_size', values='msrp', aggfunc='mean')
plt.figure(figsize=(10, 7))
sns.heatmap(pivot_table_data, annot=True, fmt=".0f", cmap='Greens',mask=pivot_table_data.isnull())

plt.title('Mean MSRP by Engine Cylinders and Vehicle Size')
plt.xlabel('Vehicle Size')
plt.ylabel('Engine Cylinders')
plt.show()

# %%
df_cleaned[(df_cleaned['vehicle_size']=='Large') & (df['engine_cylinders']==12)]
#(df_cleaned['engine_cylinders']==4)]['msrp'].mean()
# Out:
#               make          model  year             engine_fuel_type  \
# 503        Maybach             57  2010  premium unleaded (required)
# 504        Maybach             57  2010  premium unleaded (required)
# 505        Maybach             57  2010  premium unleaded (required)
# 506        Maybach             57  2011  premium unleaded (required)
# 507        Maybach             57  2011  premium unleaded (required)
# ...            ...            ...   ...                          ...
# 8327   Rolls-Royce  Silver Seraph  2001  premium unleaded (required)
# 8328   Rolls-Royce  Silver Seraph  2002  premium unleaded (required)
# 10147  Rolls-Royce         Wraith  2014  premium unleaded (required)
# 10148  Rolls-Royce         Wraith  2015  premium unleaded (required)
# 10149  Rolls-Royce         Wraith  2016  premium unleaded (required)
#
#        engine_hp  engine_cylinders transmission_type     driven_wheels  \
# ...

# %% [markdown]
# #### **06.1.3 Group by Engine Cylinders**

# %%
#df_cleaned.groupby(['engine_cylinders']).agg({'msrp': 'mean', 'popularity': 'mean'}).round()
df_cleaned.groupby(['engine_cylinders'])[['msrp','popularity']].mean().round(2)
# Out:
#                         msrp  popularity
# engine_cylinders
# 0.0                 47943.03     1773.45
# 3.0                 13547.00      791.95
# 4.0                 25528.39     1432.28
# 5.0                 24269.25      850.70
# 6.0                 36654.11     1696.64
# 8.0                 65596.86     1758.71
# 10.0               188209.77     1829.06
# 12.0               291073.94      844.11
# 16.0              1757223.67      820.00

# %%
sns.countplot(data=df_cleaned, x="engine_cylinders", hue="popularity")
# Out:
# <Axes: xlabel='engine_cylinders', ylabel='count'>

# %% [markdown]
# ### **06.2 Group** the data by the following columns and calculate the average ***highway MPG*** and ***city mpg*** for each group:
# *   Engine HP
# *   Popularity
# *   MSRP

# %% [markdown]
# ###### **06.2.1 Group by Engine_HP** for columns ***highway MPG*** and ***city_mpg*** / (calculate the **average**)

# %%
#df_cleaned.groupby(['engine_hp']).agg({'highway_mpg': 'mean', 'city_mpg': 'mean'}).round()
df_cleaned.groupby(['engine_hp'])[['highway_mpg','city_mpg']].mean().round(2)
# Out:
#            highway_mpg  city_mpg
# engine_hp
# 55.0             41.50     33.00
# 63.0             38.00     29.67
# 66.0             75.67     90.33
# 74.0             43.11     35.67
# 78.0             41.88     35.00
# ...                ...       ...
# 707.0            21.67     13.00
# 720.0            17.00     10.50
# 731.0            16.00     11.00
# 750.0            18.00     11.00
# 1001.0           14.00      8.00
#
# [342 rows x 2 columns]

# %%
grouped_mpg = df_cleaned.groupby(['engine_hp'])[['highway_mpg','city_mpg']].mean().round(2)

plt.figure(figsize=(15, 7))

# Plot highway_MPG in green
sns.lineplot(x=grouped_mpg.index, y=grouped_mpg['highway_mpg'], color='green', label='Highway MPG')

# Plot city_mpg in red
sns.lineplot(x=grouped_mpg.index, y=grouped_mpg['city_mpg'], color='red', label='City MPG')

plt.title('Average Highway and City MPG by Engine HP')
plt.xlabel('Engine HP')
plt.ylabel('Average MPG')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ###### **06.2.2 Group by Popularity**

# %%
#df._cleaned.groupby(['popularity']).agg({'highway_mpg': 'mean', 'city_mpg': 'mean'}).round()
df_cleaned.groupby(['popularity'])[['highway_mpg','city_mpg']].mean().round(2)
# Out:
#             highway_mpg  city_mpg
# popularity
# 2                 18.00     13.00
# 21                25.33     16.33
# 26                25.95     17.47
# 61                24.59     18.01
# 67                16.00     10.00
# 86                19.13     11.84
# 105               32.30     25.32
# 113               34.00     24.00
# 130               17.29     13.53
# 155               27.14     18.92
# 190               24.82     17.85
# 204               28.49     20.21
# 210               26.13     18.08
# 238               20.16     13.20
# 258               22.03     16.17
# 259               18.93     12.56
# 376               26.38     17.76
# 416               22.20     15.60
# 436               28.01     22.34
# 454               25.90     20.34
# 481               26.00     19.83
# 520               18.91     11.55
# 535               26.55     19.00
# 549               21.56     15.84
# 586               28.05     21.42
# 613               26.11     18.68
# ...

# %% [markdown]
# ###### **06.2.3 Group by MSRP**

# %%
df_cleaned.groupby(['msrp'])[['highway_mpg','city_mpg']].mean().round(2)
# Out:
#          highway_mpg  city_mpg
# msrp
# 2000           25.93     19.02
# 2002           23.00     19.00
# 2003           34.00     27.00
# 2008           24.00     18.00
# 2012           35.00     28.00
# ...              ...       ...
# 1380000        16.00     10.00
# 1382750        16.00     10.00
# 1500000        14.00      8.50
# 1705769        14.00      8.00
# 2065902        14.00      8.00
#
# [5978 rows x 2 columns]

# %%
df_cleaned.groupby(['msrp'])[['highway_mpg','city_mpg']].mean().round(2)

plt.figure(figsize=(15, 7))

# Plot highway_MPG in green
sns.lineplot(x=grouped_mpg.index, y=grouped_mpg['highway_mpg'], color='green', label='Highway MPG')

# Plot city_mpg in red
sns.lineplot(x=grouped_mpg.index, y=grouped_mpg['city_mpg'], color='red', label='City MPG')

plt.title('Average Highway and City MPG by MSRP')
plt.xlabel('MSRP')
plt.ylabel('Average MPG')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
fig, axes = plt.subplots(3, 1, figsize=(15, 21))
fig.suptitle('Average Highway and City MPG by Engine HP, Popularity, and MSRP', fontsize=16, y=1.02)

# Data for Engine_HP plot (already calculated as grouped_mpg)
grouped_mpg_hp = df_cleaned.groupby(['engine_hp'])[['highway_mpg','city_mpg']].mean().round(2)

# Plot 1: Average Highway and City MPG by Engine HP
sns.lineplot(x=grouped_mpg_hp.index, y=grouped_mpg_hp['highway_mpg'], color='green', label='Highway MPG', ax=axes[0])
sns.lineplot(x=grouped_mpg_hp.index, y=grouped_mpg_hp['city_mpg'], color='red', label='City MPG', ax=axes[0])
axes[0].set_title('Average Highway and City MPG by Engine HP')
axes[0].set_xlabel('Engine HP')
axes[0].set_ylabel('Average MPG')
axes[0].legend()
axes[0].grid(True, linestyle='--', alpha=0.7)

# Data for Popularity plot
grouped_mpg_popularity = df_cleaned.groupby(['popularity'])[['highway_mpg','city_mpg']].mean().round(2)

# Plot 2: Average Highway and City MPG by Popularity
sns.lineplot(x=grouped_mpg_popularity.index, y=grouped_mpg_popularity['highway_mpg'], color='green', label='Highway MPG', ax=axes[1])
sns.lineplot(x=grouped_mpg_popularity.index, y=grouped_mpg_popularity['city_mpg'], color='red', label='City MPG', ax=axes[1])
axes[1].set_title('Average Highway and City MPG by Popularity')
axes[1].set_xlabel('Popularity')
axes[1].set_ylabel('Average MPG')
axes[1].legend()
axes[1].grid(True, linestyle='--', alpha=0.7)

# Data for MSRP plot
grouped_mpg_msrp = df_cleaned.groupby(['msrp'])[['highway_mpg','city_mpg']].mean().round(2)

# Plot 3: Average Highway and City MPG by MSRP
sns.lineplot(x=grouped_mpg_msrp.index, y=grouped_mpg_msrp['highway_mpg'], color='green', label='Highway MPG', ax=axes[2])
sns.lineplot(x=grouped_mpg_msrp.index, y=grouped_mpg_msrp['city_mpg'], color='red', label='City MPG', ax=axes[2])
axes[2].set_title('Average Highway and City MPG by MSRP')
axes[2].set_xlabel('MSRP')
axes[2].set_ylabel('Average MPG')
axes[2].legend()
axes[2].grid(True, linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0.03, 1, 0.98])
plt.show()

# %% [markdown]
# **obs.: a clear comparison of fuel efficiency against these variables.**

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 20))
fig.suptitle('Distribution of MSRP by Vehicle Size, Driven Wheels, and Engine Cylinders', fontsize=16, y=1.02)

# Plot 1: Distribution of MSRP by Vehicle Size
sns.violinplot(x='vehicle_size', y='msrp', data=df_cleaned, hue='vehicle_size', legend=False, palette='viridis', ax=axes[0])
axes[0].set_title('Distribution of MSRP by Vehicle Size')
axes[0].set_xlabel('Vehicle Size')
axes[0].set_ylabel('MSRP')
axes[0].grid(True, linestyle='--', alpha=0.7)
plt.setp(axes[0].get_xticklabels(), rotation=45, ha='right')

# Plot 2: Distribution of MSRP by Driven_Wheels
sns.violinplot(x='driven_wheels', y='msrp', data=df_cleaned, hue='driven_wheels', legend=False, palette='Reds', ax=axes[1])
axes[1].set_title('Distribution of MSRP by Driven_Wheels')
axes[1].set_xlabel('Driven_Wheels')
axes[1].set_ylabel('MSRP')
axes[1].grid(True, linestyle='--', alpha=0.7)
plt.setp(axes[1].get_xticklabels(), rotation=45, ha='right')

# Plot 3: Distribution of MSRP vs Engine_Cylinders
sns.violinplot(x='engine_cylinders', y='msrp', data=df_cleaned, hue='engine_cylinders', legend=False, palette='Blues', ax=axes[2])
axes[2].set_title('Distribution of MSRP vs Engine_Cylinders')
axes[2].set_xlabel('Engine_Cylinders')
axes[2].set_ylabel('MSRP')
axes[2].grid(True, linestyle='--', alpha=0.7)
plt.setp(axes[2].get_xticklabels(), rotation=45, ha='right')

plt.tight_layout(rect=[0, 0.03, 1, 0.98])
plt.show()

# %%
# Statistical summary for numerical columns
df_cleaned.describe()
# Out:
#                year     engine_hp  engine_cylinders  number_of_doors  \
# count  10603.000000  10603.000000      10603.000000     10603.000000
# mean    2011.751297    258.854664          5.682920         3.482411
# std        5.906467    109.384079          1.814236         0.857926
# min     1995.000000     55.000000          0.000000         2.000000
# 25%     2008.000000    180.000000          4.000000         3.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    305.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway_mpg      city_mpg   popularity          msrp     Total_MPG  \
# count  10603.000000  10603.000000  10603.00000  1.060300e+04  10603.000000
# mean      26.746298     19.831840   1575.32736  4.415901e+04     23.289069
# std        9.120727      9.371049   1459.06585  6.249507e+04      8.978301
# ...

# %%
sns.heatmap(df_cleaned.select_dtypes(include='number').corr(), annot=True, fmt=".2f", cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## **07. Total_MPG_bin** new feature

# %%
# Create a bin feature
df_cleaned['Total_MPG_bin'] = pd.qcut(df_cleaned.Total_MPG, q=4)

# %%
df_cleaned['Total_MPG_bin'] = pd.qcut(df_cleaned.Total_MPG, q=4)
df_cleaned[['Total_MPG', 'Total_MPG_bin']]
# Out:
#        Total_MPG Total_MPG_bin
# 0           22.5  (22.0, 26.0]
# 1           23.5  (22.0, 26.0]
# 2           24.0  (22.0, 26.0]
# 3           23.0  (22.0, 26.0]
# 4           23.0  (22.0, 26.0]
# ...          ...           ...
# 10598       19.5  (19.0, 22.0]
# 10599       19.5  (19.0, 22.0]
# 10600       19.5  (19.0, 22.0]
# 10601       19.5  (19.0, 22.0]
# 10602       21.5  (19.0, 22.0]
#
# [10603 rows x 2 columns]

# %%
df_cleaned.Total_MPG_bin.value_counts()
# Out:
# Total_MPG_bin
# (9.499, 19.0]    3024
# (26.0, 189.0]    2638
# (19.0, 22.0]     2601
# (22.0, 26.0]     2340
# Name: count, dtype: int64

# %% [markdown]
# ### !!! NaN

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='engine_hp', y='Total_MPG', hue='transmission_type')
plt.title('Scatterplot of Engine HP vs Total MPG')
plt.xlabel('Engine HP')
plt.ylabel('Total MPG')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='engine_hp', y='Total_MPG', hue='transmission_type')
plt.title('Scatterplot of Engine HP vs Total MPG (Zoomed)')
plt.xlabel('Engine HP')
plt.ylabel('Total MPG')
plt.xlim(50, 700)  # Example: set x-axis limits from 50 to 400
plt.ylim(10, 125)   # Example: set y-axis limits from 10 to 50
plt.show()

# %%
df_cleaned.groupby(["transmission_type"])["engine_hp"].median()
# Out:
# transmission_type
# AUTOMATED_MANUAL    252.0
# AUTOMATIC           260.0
# DIRECT_DRIVE        185.0
# MANUAL              190.0
# UNKNOWN             190.0
# Name: engine_hp, dtype: float64

# %% [markdown]
# **other visualisations**

# %% [markdown]
#   ***A histogram ***helps visualize the **distribution** of a ***single variable***, identifying **skewness**, **outliers**, **modes (peaks)**, and **spread**, making it useful for understanding central tendencies and variability in data.

# %%
#plt.figure(figsize=(25, 10))

plt.hist(df_cleaned.city_mpg, bins=75, edgecolor='green')
plt.title('Histogram of mpg')
plt.xlabel('city_mpg') # X-axis label
plt.ylabel('Frequency') # Y-axis label
plt.grid(True)

plt.show()

# %%
#plt.figure(figsize=(5, 7))

plt.hist(df_cleaned.engine_hp, bins=7, edgecolor='white')
plt.title('Histogram of Engine HP')
plt.xlabel('Engine HP') # X-axis label
plt.ylabel('Frequency') # Y-axis label
plt.grid(True)

plt.show()

# %%
#plt.figure(figsize=(10, 6))  # Set figure size
sns.countplot(data=df_cleaned, x='engine_cylinders', hue='year')  # Create countplot
plt.xlabel('Year')  # X-axis label
plt.ylabel('Count')  # Y-axis label
plt.title('Count Plot of Engine Cylinders by Y')
plt.ylabel('Count')  # Y-axis label
plt.title('Count Plot of Engine Cylinders by Year')
plt.grid(True)

plt.show()

# %%
display(df_cleaned.head())
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   vehicle_size vehicle_style  highway_mpg  city_mpg  popularity   msrp  \
# ...

# %%
df_direct_drive = df_cleaned[df_cleaned['transmission_type'] == 'DIRECT_DRIVE']
display(df_direct_drive)
# Out:
#                make                   model  year engine_fuel_type  engine_hp  \
# 435            FIAT                    500e  2015         electric      160.0
# 436            FIAT                    500e  2016         electric      160.0
# 437            FIAT                    500e  2017         electric      160.0
# 1485  Mercedes-Benz  B-Class Electric Drive  2015         electric      177.0
# 1486  Mercedes-Benz  B-Class Electric Drive  2016         electric      177.0
# ...             ...                     ...   ...              ...        ...
# 8743      Chevrolet                Spark EV  2014         electric      140.0
# 8744      Chevrolet                Spark EV  2015         electric      140.0
# 8745      Chevrolet                Spark EV  2015         electric      140.0
# 8746      Chevrolet                Spark EV  2016         electric      140.0
# 8747      Chevrolet                Spark EV  2016         electric      140.0
#
# ...

# %% [markdown]
# # **Summary**
#
# of the 'Midsize' vehicle category, which is derived from our cleaned and filtered dataset, highlights several key characteristics:
#
# **Midsize Vehicle Characteristics** (based on cleaned data):
#
# - Mean **MSRP**: Approximately **$41,505.44**.
#
# This positions Midsize vehicles robustly between 'Compact' (mean MSRP ~$$41,505.44**.
#
# This positions Midsize vehicles robustly between 'Compact' (mean MSRP ~$38,408) and 'Large' (mean MSRP ~$57,177) categories.
#
# This figure is more reliable due to the prior handling of MSRP outliers.
#
# - Mean **Popularity**: Around 1,464.65.
#
# Similar to MSRP, its popularity score is intermediate, providing a balanced view after removing duplicate entries.
#
# - Mean **Engine Cylinders**: Averaging 5.30 cylinders.
#
# This is higher than 'Compact' vehicles (mean ~4.57) but lower than 'Large' vehicles (mean ~6.86).
#
# The accuracy of this average is improved by addressing missing engine_cylinders values, especially for electric cars and specific manufacturers like Mazda.
#
# **Impact of Filtering and Cleaning on these Insights:**
#
# Our analysis benefits significantly from the preceding data wrangling steps:
#
# **Column Name Standardization**: Lowercasing and replacing spaces with underscores in column names ensured consistency for analysis.
#
# **Year Filtering**: Removing vehicles older than 1995 focused the dataset on more modern and relevant vehicles, preventing historical outliers from skewing averages.
#
# **Duplicate Removal**: Dropping 487 duplicate rows  ensured that each unique vehicle entry contributed fairly to the statistical calculations, preventing overrepresentation.
#
# **Handling Missing Values:**
# - ngine_fuel_type missing values were imputed based on context).
# - engine_hp missing values were carefully replaced using contextual information (e.g., median for specific makes/types) rather than simple global imputation .
#
# This ensures that the engine performance statistics for Midsize vehicles are as accurate as possible.
# - engine_cylinders missing values were specifically addressed, assigning 0 for electric vehicles and appropriate values for others like Mazda.
#
# This is crucial for accurate engine-related analysis within the Midsize category, especially when identifying outliers.
#
# - number_of_doors missing values were also imputed .
# These cleaning efforts directly confirm the reality of the data presented for the 'Midsize' category, ensuring that the statistics and observations accurately reflect the characteristics of these vehicles within the refined dataset.
